# %% [markdown]
# <a href="https://colab.research.google.com/github/diogosec/Statistics-Applied-to-Computing/blob/main/Mapa_do_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.0 MB 3.7 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 40.2 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 402 kB/s
# ...

# %%
import geopandas as gpd

# %%
Brasil = gpd.read_file('/content/drive/MyDrive/Colab Notebooks/arquivos/BR_Mun/BR_Municipios_2021.shp')

# %%
Paraiba = gpd.read_file('/content/drive/MyDrive/Colab Notebooks/arquivos/PB_Setores_2020.zip (Unzipped Files)/PB_Setores_2020.shp')

# %%
Soledade = gpd.read_file('/content/drive/MyDrive/Colab Notebooks/arquivos/Soledade_Setores/2516102_Soledade_Setores_2020_1-polygon.shp')

# %%
Brasil.plot(figsize=(7,7)), Paraiba.plot(figsize=(7,7)), Soledade.plot(figsize=(7,7))
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f0020564f10>,
# ...
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f0020651d10>)
